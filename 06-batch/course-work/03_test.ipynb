# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-21-openjdk-amd64"

# %%
import pyspark

# %%
pyspark.__version__
# Out:
# '4.1.1'

# %%
pyspark.__file__
# Out:
# '/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/__init__.py'

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .master('local[2]') \
    .appName('test') \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/15 22:44:28 WARN Utils: Your hostname, codespaces-472bba, resolves to a loopback address: 127.0.0.1; using 10.0.14.188 instead (on interface eth0)
# 26/03/15 22:44:28 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/15 22:44:33 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark.version
# Out:
# '4.1.1'

# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Out:
# --2026-03-10 18:06:15--  https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response...
# 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/513814948/5a2cc2f5-b4cd-4584-9c62-a6ea97ed0e6a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-10T18%3A45%3A52Z&rscd=attachment%3B+filename%3Dtaxi_zone_lookup.csv&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-10T17%3A45%3A33Z&ske=2026-03-10T18%3A45%3A52Z&sks=b&skv=2018-11-09&sig=V7%2B1yNjOxVQjPuzTRco6hcmtEoLyS2AKKFYFCtFbvCk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MzE2NjI3NSwibmJmIjoxNzczMTY1OTc1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.yaexhUtY1l1MLeseJdnOyCeXPxNxpGy4UHdwUe_7qmc&response-content-disposition=attachment%3B%20filename%3Dtaxi_zone_lookup.csv&response-content-type=application%2Foctet-stream [following]
# --2026-03-10 18:06:15--  https://release-assets.githubusercontent.com/github-production-release-asset/513814948/5a2cc2f5-b4cd-4584-9c62-a6ea97ed0e6a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-10T18%3A45%3A52Z&rscd=attachment%3B+filename%3Dtaxi_zone_lookup.csv&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-10T17%3A45%3A33Z&ske=2026-03-10T18%3A45%3A52Z&sks=b&skv=2018-11-09&sig=V7%2B1yNjOxVQjPuzTRco6hcmtEoLyS2AKKFYFCtFbvCk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MzE2NjI3NSwibmJmIjoxNzczMTY1OTc1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.yaexhUtY1l1MLeseJdnOyCeXPxNxpGy4UHdwUe_7qmc&response-content-disposition=attachment%3B%20filename%3Dtaxi_zone_lookup.csv&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12322 (12K) [application/octet-stream]
# Saving to: ‘taxi_zone_lookup.csv.1’
#
# taxi_zone_lookup.cs 100%[===================>]  12.03K  --.-KB/s    in 0s
#
# 2026-03-10 18:06:15 (68.6 MB/s) - ‘taxi_zone_lookup.csv.1’ saved [12322/12322]

# %%
# !head taxi_zone_lookup.csv
# Out:
# "LocationID","Borough","Zone","service_zone"
# 1,"EWR","Newark Airport","EWR"
# 2,"Queens","Jamaica Bay","Boro Zone"
# 3,"Bronx","Allerton/Pelham Gardens","Boro Zone"
# 4,"Manhattan","Alphabet City","Yellow Zone"
# 5,"Staten Island","Arden Heights","Boro Zone"
# 6,"Staten Island","Arrochar/Fort Wadsworth","Boro Zone"
# 7,"Queens","Astoria","Boro Zone"
# 8,"Queens","Astoria Park","Boro Zone"
# 9,"Queens","Auburndale","Boro Zone"

# %%
df = spark.read \
    .option('header', 'true') \
    .csv('taxi_zone_lookup.csv')

# %%
df.show()
# Out:
# +----------+-------------+--------------------+------------+
# |LocationID|      Borough|                Zone|service_zone|
# +----------+-------------+--------------------+------------+
# |         1|          EWR|      Newark Airport|         EWR|
# |         2|       Queens|         Jamaica Bay|   Boro Zone|
# |         3|        Bronx|Allerton/Pelham G...|   Boro Zone|
# |         4|    Manhattan|       Alphabet City| Yellow Zone|
# |         5|Staten Island|       Arden Heights|   Boro Zone|
# |         6|Staten Island|Arrochar/Fort Wad...|   Boro Zone|
# |         7|       Queens|             Astoria|   Boro Zone|
# |         8|       Queens|        Astoria Park|   Boro Zone|
# |         9|       Queens|          Auburndale|   Boro Zone|
# |        10|       Queens|        Baisley Park|   Boro Zone|
# |        11|     Brooklyn|          Bath Beach|   Boro Zone|
# |        12|    Manhattan|        Battery Park| Yellow Zone|
# |        13|    Manhattan|   Battery Park City| Yellow Zone|
# |        14|     Brooklyn|           Bay Ridge|   Boro Zone|
# |        15|       Queens|Bay Terrace/Fort ...|   Boro Zone|
# |        16|       Queens|             Bayside|   Boro Zone|
# |        17|     Brooklyn|             Bedford|   Boro Zone|
# |        18|        Bronx|        Bedford Park|   Boro Zone|
# |        19|       Queens|           Bellerose|   Boro Zone|
# |        20|        Bronx|             Belmont|   Boro Zone|
# +----------+-------------+--------------------+------------+
# only showing top 20 rows

# %%
df.write.parquet('zones')

# %%
# !ls -lh
# %cd zones/
# !ls -lh
# %cd ..
# Out:
# total 36K
# -rw-rw-rw-  1 codespace codespace    0 Mar 10 17:39 01_first.ipynb
# -rw-rw-rw-  1 codespace codespace  13K Jul 19  2022 taxi_zone_lookup.csv
# -rw-rw-rw-  1 codespace codespace  13K Jul 19  2022 taxi_zone_lookup.csv.1
# drwxr-xr-x+ 2 codespace codespace 4.0K Mar 10 18:07 zones
# /workspaces/de-zoomcamp-26/06-batch/notebooks/zones
# total 8.0K
# -rw-r--r-- 1 codespace codespace    0 Mar 10 18:07 _SUCCESS
# -rw-r--r-- 1 codespace codespace 5.8K Mar 10 18:07 part-00000-7840ac46-559c-4755-afcf-fa4d3ae32fe2-c000.snappy.parquet
# /workspaces/de-zoomcamp-26/06-batch/notebooks
# Bad pipe message: %s [b'"Not:A-Brand";v="99", "Google Chrome";v="145", "Chromium"']
# Bad pipe message: %s [b'="145"\r\nsec-ch-ua-mobile: ?0\r\nsec-ch-ua-platform: "Windows']
# Bad pipe message: %s [b'\nDNT: 1\r\nUpgrade-Insecure-Request', b' 1\r\nUser-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 ']
# Bad pipe message: %s [b'fari/537.36\r\nAccept: text/html,application/xhtml+xml,application/xml;q=0.9,image/a', b'f,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nSec-Fetch-Site: none\r\nSec-Fetch-Mode: navig', b'e\r\nSec-Fetch-User: ?1\r\nSec-Fetch-Dest: document\r\nAccept-Encoding: gzip, deflate, br, zstd\r\nAccep']
# Bad pipe message: %s [b'Language: en-US,en;q=0.9,ru;q=0.8\r\nCookie: username-127-0-0-1-8888="2|1:0|10:1770724319|23:username-127-0-0-1-8888|', b'0:eyJ1c2VybmFtZSI6ICIwYWY1NzI0NWQ0NjM0NjA5YTQyN2V']
# Bad pipe message: %s [b'GFiZjQ2YWU0ZSIsICJuYW1lIjogIkFub255bW91cyBPcnRob3NpZSIsICJkaXNwbGF5X25hbWUiOiAiQW5vbnltb3VzIE9ydGhvc2ll']
# Bad pipe message: %s [b'ol: max-age=0\r\nsec-ch-ua: "Not:A-Brand";v="99", "Google Chrome";v="145", "Chromium";v="145"\r\nsec-ch-ua-mobile: ?0\r\n']
# Bad pipe message: %s [b'c-ch-ua-platform: "Windows"\r\nDNT: 1\r\nUpgrade-Insecure-Requests: 1\r\nUser-Agent: Mozilla/5.0 (Windows NT 10.0; Win64', b'x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0']
# Bad pipe message: %s [b' Safari/537.36\r\nAccept: text/html,application']
# Bad pipe message: %s [b'html+xml,application/xml;q=0.9,image/avif,imag']
# Bad pipe message: %s [b'webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nSec-Fetch-Site: none\r\nSec-Fetch-Mo', b': navigate\r\nSec-Fetch-User: ?1\r\nSec-Fetch-Dest: document\r\nAccept-Encoding: gzip, deflate, br, zstd\r', b'ccept-Lan', b'age: en-US,en;q=0.9,ru;q=0.8\r\nCookie: username-127-0-0-1-8888="2|1:0|10:1770724319|23:username-127-0-0', b'-8888|200:eyJ1c2VybmFtZSI6ICIwYWY1NzI0NWQ0Nj', b'NjA5YTQyN2VhNGFiZjQ2YWU0ZSIsICJuYW1lIjogIkFub255bW91cyBPcnRob3NpZSIsICJkaXNw']
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 35214)
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 349, in process_request
#     self.finish_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 761, in __init__
#     self.handle()
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 300, in handle
#     poll(authenticate_and_accum_updates)
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 272, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 293, in authenticate_and_accum_updates
#     raise ValueError(
# ValueError: The value of the provided token to the AccumulatorServer is not correct.
# ----------------------------------------
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 35228)
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 349, in process_request
#     self.finish_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 761, in __init__
#     self.handle()
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 300, in handle
#     poll(authenticate_and_accum_updates)
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 272, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 293, in authenticate_and_accum_updates
#     raise ValueError(
# ValueError: The value of the provided token to the AccumulatorServer is not correct.
# ----------------------------------------
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 35240)
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 349, in process_request
#     self.finish_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 761, in __init__
#     self.handle()
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 300, in handle
#     poll(authenticate_and_accum_updates)
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 272, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 293, in authenticate_and_accum_updates
#     raise ValueError(
# ValueError: The value of the provided token to the AccumulatorServer is not correct.
# ----------------------------------------
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 54208)
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 349, in process_request
#     self.finish_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 761, in __init__
#     self.handle()
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 300, in handle
#     poll(authenticate_and_accum_updates)
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 272, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 293, in authenticate_and_accum_updates
#     raise ValueError(
# ValueError: The value of the provided token to the AccumulatorServer is not correct.
# ----------------------------------------
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 54222)
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 349, in process_request
#     self.finish_request(request, client_address)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/codespace/.python/current/lib/python3.12/socketserver.py", line 761, in __init__
#     self.handle()
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 300, in handle
#     poll(authenticate_and_accum_updates)
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 272, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/workspaces/de-zoomcamp-26/06-batch/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 293, in authenticate_and_accum_updates
#     raise ValueError(
# ValueError: The value of the provided token to the AccumulatorServer is not correct.
# ----------------------------------------

# %%
# spark.stop()
